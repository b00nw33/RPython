# %% [markdown]
# # **PyCaret**
# Inspired by [Greg Hogg](https://www.youtube.com/watch?v=NbBoZQZ3bxo).
#
# [PyCaret](https://pycaret.gitbook.io/docs/get-started/tutorials) promises **low code** Machine Learning.

# %%
# Restart runtime after running this!
# !pip install --pre pycaret

# %% [markdown]
# ## Regression
# `Regression` is used to predict quantitative variables (e.g. housing prices, insurance premiums) based on a given set of features.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/timothypesi/Data-Sets-For-Machine-Learning-/main/california_housing_train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
from pycaret.regression import *

s = setup(df, target='median_house_value')
# Out:
# <style type="text/css">
# #T_6946c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6946c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6946c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6946c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6946c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6946c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6946c_row0_col1" class="data row0 col1" >8365</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6946c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6946c_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6946c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6946c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6946c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6946c_row3_col1" class="data row3 col1" >(17000, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6946c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6946c_row4_col1" class="data row4 col1" >(17000, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6946c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6946c_row5_col1" class="data row5 col1" >(11900, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6946c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6946c_row6_col1" class="data row6 col1" >(5100, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6946c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6946c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6946c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6946c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6946c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6946c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6946c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6946c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6946c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6946c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6946c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_6946c_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6946c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_6946c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6946c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_6946c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6946c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_6946c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6946c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_6946c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6946c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_6946c_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6946c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6946c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_6946c_row18_col1" class="data row18 col1" >4df7</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_fd79d th {
#   text-align: left;
# }
# #T_fd79d_row0_col0, #T_fd79d_row0_col6, #T_fd79d_row1_col0, #T_fd79d_row1_col1, #T_fd79d_row1_col2, #T_fd79d_row1_col3, #T_fd79d_row1_col4, #T_fd79d_row1_col5, #T_fd79d_row2_col0, #T_fd79d_row2_col1, #T_fd79d_row2_col2, #T_fd79d_row2_col3, #T_fd79d_row2_col4, #T_fd79d_row2_col5, #T_fd79d_row2_col6, #T_fd79d_row3_col0, #T_fd79d_row3_col1, #T_fd79d_row3_col2, #T_fd79d_row3_col3, #T_fd79d_row3_col4, #T_fd79d_row3_col5, #T_fd79d_row3_col6, #T_fd79d_row4_col0, #T_fd79d_row4_col1, #T_fd79d_row4_col2, #T_fd79d_row4_col3, #T_fd79d_row4_col4, #T_fd79d_row4_col5, #T_fd79d_row4_col6, #T_fd79d_row5_col0, #T_fd79d_row5_col1, #T_fd79d_row5_col2, #T_fd79d_row5_col3, #T_fd79d_row5_col4, #T_fd79d_row5_col5, #T_fd79d_row5_col6, #T_fd79d_row6_col0, #T_fd79d_row6_col1, #T_fd79d_row6_col2, #T_fd79d_row6_col3, #T_fd79d_row6_col4, #T_fd79d_row6_col5, #T_fd79d_row6_col6, #T_fd79d_row7_col0, #T_fd79d_row7_col1, #T_fd79d_row7_col2, #T_fd79d_row7_col3, #T_fd79d_row7_col4, #T_fd79d_row7_col5, #T_fd79d_row7_col6, #T_fd79d_row8_col0, #T_fd79d_row8_col1, #T_fd79d_row8_col2, #T_fd79d_row8_col3, #T_fd79d_row8_col4, #T_fd79d_row8_col5, #T_fd79d_row8_col6, #T_fd79d_row9_col0, #T_fd79d_row9_col1, #T_fd79d_row9_col2, #T_fd79d_row9_col3, #T_fd79d_row9_col4, #T_fd79d_row9_col5, #T_fd79d_row9_col6, #T_fd79d_row10_col0, #T_fd79d_row10_col1, #T_fd79d_row10_col2, #T_fd79d_row10_col3, #T_fd79d_row10_col4, #T_fd79d_row10_col5, #T_fd79d_row10_col6, #T_fd79d_row11_col0, #T_fd79d_row11_col1, #T_fd79d_row11_col2, #T_fd79d_row11_col3, #T_fd79d_row11_col4, #T_fd79d_row11_col5, #T_fd79d_row11_col6, #T_fd79d_row12_col0, #T_fd79d_row12_col1, #T_fd79d_row12_col2, #T_fd79d_row12_col3, #T_fd79d_row12_col4, #T_fd79d_row12_col5, #T_fd79d_row12_col6, #T_fd79d_row13_col0, #T_fd79d_row13_col1, #T_fd79d_row13_col2, #T_fd79d_row13_col3, #T_fd79d_row13_col4, #T_fd79d_row13_col5, #T_fd79d_row13_col6, #T_fd79d_row14_col0, #T_fd79d_row14_col1, #T_fd79d_row14_col2, #T_fd79d_row14_col3, #T_fd79d_row14_col4, #T_fd79d_row14_col5, #T_fd79d_row14_col6, #T_fd79d_row15_col0, #T_fd79d_row15_col1, #T_fd79d_row15_col2, #T_fd79d_row15_col3, #T_fd79d_row15_col4, #T_fd79d_row15_col5, #T_fd79d_row15_col6, #T_fd79d_row16_col0, #T_fd79d_row16_col1, #T_fd79d_row16_col2, #T_fd79d_row16_col3, #T_fd79d_row16_col4, #T_fd79d_row16_col5, #T_fd79d_row16_col6, #T_fd79d_row17_col0, #T_fd79d_row17_col1, #T_fd79d_row17_col2, #T_fd79d_row17_col3, #T_fd79d_row17_col4, #T_fd79d_row17_col5, #T_fd79d_row17_col6 {
#   text-align: left;
# }
# #T_fd79d_row0_col1, #T_fd79d_row0_col2, #T_fd79d_row0_col3, #T_fd79d_row0_col4, #T_fd79d_row0_col5, #T_fd79d_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd79d_row0_col7, #T_fd79d_row1_col7, #T_fd79d_row2_col7, #T_fd79d_row3_col7, #T_fd79d_row4_col7, #T_fd79d_row5_col7, #T_fd79d_row6_col7, #T_fd79d_row7_col7, #T_fd79d_row8_col7, #T_fd79d_row9_col7, #T_fd79d_row10_col7, #T_fd79d_row11_col7, #T_fd79d_row12_col7, #T_fd79d_row13_col7, #T_fd79d_row14_col7, #T_fd79d_row15_col7, #T_fd79d_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd79d_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd79d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd79d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd79d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fd79d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fd79d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fd79d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fd79d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fd79d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fd79d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd79d_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_fd79d_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fd79d_row0_col1" class="data row0 col1" >32604.5785</td>
#       <td id="T_fd79d_row0_col2" class="data row0 col2" >2337020176.4911</td>
#       <td id="T_fd79d_row0_col3" class="data row0 col3" >48318.7329</td>
#       <td id="T_fd79d_row0_col4" class="data row0 col4" >0.8272</td>
#       <td id="T_fd79d_row0_col5" class="data row0 col5" >0.2376</td>
#       <td id="T_fd79d_row0_col6" class="data row0 col6" >0.1814</td>
#       <td id="T_fd79d_row0_col7" class="data row0 col7" >0.2070</td>
#     </tr>
#     <tr>
#       <th id="T_fd79d_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_fd79d_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_fd79d_row1_col1" class="data row1 col1" >33008.9457</td>
#       <td id="T_fd79d_row1_col2" class="data row1 col2" >2535422814.3850</td>
#       <td id="T_fd79d_row1_col3" class="data row1 col3" >50328.2610</td>
#       <td id="T_fd79d_row1_col4" class="data row1 col4" >0.8126</td>
#       <td id="T_fd79d_row1_col5" class="data row1 col5" >0.2381</td>
#       <td id="T_fd79d_row1_col6" class="data row1 col6" >0.1813</td>
#       <td id="T_fd79d_row1_col7" class="data row1 col7" >4.6010</td>
#     </tr>
#     <tr>
#       <th id="T_fd79d_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_fd79d_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_fd79d_row2_col1" class="data row2 col1" >35709.3854</td>
#       <td id="T_fd79d_row2_col2" class="data row2 col2" >2833030403.4134</td>
#       <td id="T_fd79d_row2_col3" class="data row2 col3" >53200.1279</td>
#       <td id="T_fd79d_row2_col4" class="data row2 col4" >0.7905</td>
#       <td id="T_fd79d_row2_col5" class="data row2 col5" >0.2497</td>
#       <td id="T_fd79d_row2_col6" class="data row2 col6" >0.1963</td>
#       <td id="T_fd79d_row2_col7" class="data row2 col7" >1.9180</td>
#     </tr>
#     <tr>
#       <th id="T_fd79d_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_fd79d_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fd79d_row3_col1" class="data row3 col1" >38027.8540</td>
#       <td id="T_fd79d_row3_col2" class="data row3 col2" >3007075468.0443</td>
#       <td id="T_fd79d_row3_col3" class="data row3 col3" >54805.5873</td>
#       <td id="T_fd79d_row3_col4" class="data row3 col4" >0.7777</td>
#       <td id="T_fd79d_row3_col5" class="data row3 col5" >0.2680</td>
#       <td id="T_fd79d_row3_col6" class="data row3 col6" >0.2143</td>
#       <td id="T_fd79d_row3_col7" class="data row3 col7" >1.4220</td>
#     </tr>
#     <tr>
#       <th id="T_fd79d_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_fd79d_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_fd79d_row4_col1" class="data row4 col1" >50682.5887</td>
#       <td id="T_fd79d_row4_col2" class="data row4 col2" >4741509043.2000</td>
#       <td id="T_fd79d_row4_col3" class="data row4 col3" >68795.9672</td>
#       <td id="T_fd79d_row4_col4" class="data row4 col4" >0.6497</td>
#       <td id="T_fd79d_row4_col5" class="data row4 col5" >0.4224</td>
#       <td id="T_fd79d_row4_col6" class="data row4 col6" >0.3030</td>
#       <td id="T_fd79d_row4_col7" class="data row4 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_fd79d_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_fd79d_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_fd79d_row5_col1" class="data row5 col1" >50682.3668</td>
#       <td id="T_fd79d_row5_col2" class="data row5 col2" >4741508249.6000</td>
#       <td id="T_fd79d_row5_col3" class="data row5 col3" >68795.9621</td>
#       <td id="T_fd79d_row5_col4" class="data row5 col4" >0.6497</td>
#       <td id="T_fd79d_row5_col5" class="data row5 col5" >0.4238</td>
#       <td id="T_fd79d_row5_col6" class="data row5 col6" >0.3030</td>
#       <td id="T_fd79

# %%
finalize_model(best)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['longitude', 'latitude',
#                                              'housing_median_age',
#                                              'total_rooms', 'total_bedrooms',
#                                              'population', 'households',
#                                              'median_income'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator', LGBMRegressor(random_state=8365))])

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c831">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c831_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2c831_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2c831_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2c831_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2c831_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2c831_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2c831_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c831_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c831_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2c831_row0_col1" class="data row0 col1" >32528.4274</td>
#       <td id="T_2c831_row0_col2" class="data row0 col2" >2340428482.2405</td>
#       <td id="T_2c831_row0_col3" class="data row0 col3" >48377.9752</td>
#       <td id="T_2c831_row0_col4" class="data row0 col4" >0.8235</td>
#       <td id="T_2c831_row0_col5" class="data row0 col5" >0.2416</td>
#       <td id="T_2c831_row0_col6" class="data row0 col6" >0.1853</td>
#     </tr>
#   </tbody>
# </table>
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11900 -117.110001  32.910000                15.0       1840.0           235.0
# 11901 -118.150002  33.849998                30.0       4071.0          1067.0
# 11902 -121.949997  37.810001                 5.0       7178.0           898.0
# 11903 -120.959999  41.119999                29.0        779.0           136.0
# 11904 -122.080002  37.389999                46.0       1115.0           248.0
# ...           ...        ...                 ...          ...             ...
# 16995 -120.459999  34.709999                17.0       2830.0           430.0
# 16996 -120.250000  38.040001                22.0       4173.0           763.0
# 16997 -117.239998  32.810001                33.0       1588.0           289.0
# 16998 -117.709999  34.080002                29.0       1276.0           283.0
# 16999 -117.050003  32.950001                17.0       3039.0           555.0
#
#        population  households  median_income  median_house_value  \
# 11900       855.0       241.0         7.5992            310600.0
# 11901      2144.0       970.0         2.7268            218100.0
# 11902      2823.0       907.0         9.0776            450400.0
# 11903       364.0       123.0         2.5000             59200.0
# 11904       543.0       248.0         3.2083            334300.0
# ...           ...         ...            ...                 ...
# 16995      1035.0       416.0         4.9292            207200.0
# 16996      1086.0       444.0         2.5562            136200.0
# 16997       683.0       301.0         5.4103            332400.0
# 16998      1216.0       316.0         2.5972            134300.0
# 16999      1297.0       552.0         3.9531            178600.0
#
#        prediction_label
# 11900     327266.251812
# 11901     195707.940162
# 11902     419818.755685
# 11903      66263.394737
# 11904     254538.081485
# ...                 ...
# 16995     222598.550969
# 16996     116049.435497
# 16997     295825.365610
# 16998     116210.170847
# 16999     185581.982217
#
# [5100 rows x 10 columns]

# %%
test_df = pd.read_csv('https://raw.githubusercontent.com/timothypesi/Data-Sets-For-Machine-Learning-/main/california_housing_test.csv')

predict_model(best, test_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_12182">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12182_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_12182_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_12182_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_12182_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_12182_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_12182_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_12182_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12182_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12182_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_12182_row0_col1" class="data row0 col1" >32670.4902</td>
#       <td id="T_12182_row0_col2" class="data row0 col2" >2395166783.0923</td>
#       <td id="T_12182_row0_col3" class="data row0 col3" >48940.4412</td>
#       <td id="T_12182_row0_col4" class="data row0 col4" >0.8128</td>
#       <td id="T_12182_row0_col5" class="data row0 col5" >0.2452</td>
#       <td id="T_12182_row0_col6" class="data row0 col6" >0.1849</td>
#     </tr>
#   </tbody>
# </table>
#        longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.050003  37.369999                27.0       3885.0           661.0
# 1    -118.300003  34.259998                43.0       1510.0           310.0
# 2    -117.809998  33.779999                27.0       3589.0           507.0
# 3    -118.360001  33.820000                28.0         67.0            15.0
# 4    -119.669998  36.330002                19.0       1241.0           244.0
# ...          ...        ...                 ...          ...             ...
# 2995 -119.860001  34.419998                23.0       1450.0           642.0
# 2996 -118.139999  34.060001                27.0       5257.0          1082.0
# 2997 -119.699997  36.299999                10.0        956.0           201.0
# 2998 -117.120003  34.099998                40.0         96.0            14.0
# 2999 -119.629997  34.419998                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value  \
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
#       prediction_label
# 0        395354.292351
# 1        195596.582312
# 2        256908.972669
# 3        303431.071641
# 4         72733.402552
# ...                ...
# 2995     238061.496340
# 2996     215523.976691
# 2997      66963.331178
# 2998      87147.046880
# 2999     504083.127598
#
# [3000 rows x 10 columns]
