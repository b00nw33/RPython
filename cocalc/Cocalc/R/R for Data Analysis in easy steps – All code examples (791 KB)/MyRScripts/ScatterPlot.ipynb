# %%
x <- 1:10
y <- x^2

# %%
library( ggplot2 )

# %%
qplot( x, y )
# Out:
# plot without title

# %%
qplot( x, y, geom=c("point", "line" ) )
# Out:
# plot without title

# %%
qplot( x, y, geom=c( "point", "line" ), color=I( "Red" ) )
# Out:
# plot without title

# %%
scatter.smooth(x,y)
# Out:
# plot without title
