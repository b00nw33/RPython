# %%
ny <- c( 3.8, 5.5, 9.9, 15.7, 21.5, 26.3 )
la <- c( 19.5, 19.4, 19.7, 20.8, 21.3, 22.7 )
fw <- c( 13.7, 15.4, 20, 24.6, 28.5, 32.7 )

# %%
table <- cbind( ny, la, fw )
print( table )
# Out:
#        ny   la   fw
# [1,]  3.8 19.5 13.7
# [2,]  5.5 19.4 15.4
# [3,]  9.9 19.7 20.0
# [4,] 15.7 20.8 24.6
# [5,] 21.5 21.3 28.5
# [6,] 26.3 22.7 32.7

# %%
matplot( table[,'ny'], type="s", pch=15:17, col=2:4 )
# Out:
# plot without title
