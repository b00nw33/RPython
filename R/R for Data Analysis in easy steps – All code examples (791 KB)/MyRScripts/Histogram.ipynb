# %%
Sex <- rep( c( "Female", "Male" ), each=500 )

# %%
height <- c( rnorm( 500, 65 ), rnorm( 500, 69 ) )

# %%
frame <- data.frame( Sex, height )

# %%
head( frame, n=3 )
tail( frame, n=3 )
# Out:
#   Sex    height
# 1 Female 64.52823
# 2 Female 63.66392
# 3 Female 63.60426
#      Sex  height
# 998  Male 69.03603
# 999  Male 68.23036
# 1000 Male 67.94594

# %%
library( ggplot2 )

# %%
qplot( height, data=frame, geom="histogram", 
       fill=Sex, bins=40,
       ylab="Frequency", xlab="Height in Inches",
       main="Average Adult Height (USA)" )
# Out:
# plot without title

# %%
qplot( height, data=frame, geom="density", 
       size=I(2), color=Sex, linetype=Sex,
       ylab="Density", xlab="Height in Inches",
       main="Average Adult Height (USA)" )
# Out:
# plot without title

# %%
with(frame, qplot(height, geom='density',
                  fill=Sex, color=Sex,
                  alpha=I(.2), size=I(1.5),
                  main="Density plot")
    )
# Out:
# plot without title
